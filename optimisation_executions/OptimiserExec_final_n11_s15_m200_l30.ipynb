# %%
from optimisation_exec_ops.OptimisationConfigExecution import OptimisationParamExecution

# %%
param = {
    'n'             : 38,
    'l2'            : 0.36,
    'def_rng_seed'  : 42,
    'split_seed'    : 42,
    'cv'            : 5,
    'path_directory': '../data',
}
abc_param = {'solution_cnt': 15, 'max_iter': 200, 'trial_limit': 30, 'employed_legacy': True, 'onlooker_legacy': True}

# %%
execution = OptimisationParamExecution(**param)
execution.fit(**abc_param)
# Out:
# Seed 0:
# Run CV of job 5
