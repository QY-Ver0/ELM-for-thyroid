# %%
from optimisation_exec_ops.OptimisationConfigExecution import OptimisationParamExecution

# %%
param = {
    'n'             : 38,
    'l2'            : 0.36,
    'def_rng_seed'  : 42,
    'split_seed'    : 42,
    'cv'            : 5,
    'ver'           : 2, #this is for final
    'path_directory': '../data',
}
abc_param = {'solution_cnt': 45, 'max_iter': 200, 'trial_limit': 90, 'employed_legacy': True, 'onlooker_legacy': True, 'cv_on_train': False}

# %%
execution = OptimisationParamExecution(**param)
execution.fit(**abc_param)
