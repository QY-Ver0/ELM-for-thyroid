# %%
from optimisation_exec_ops.OptimisationConfigExecution import OptimisationParamExecution

# %%
param = {
    'n'             : 38,
    'l2'            : 0.36,
    'def_rng_seed'  : 42,
    'split_seed'    : 42,
    'cv'            : 5,
    'ver'           : 2, #this is for final
    'path_directory': '../data',
}
abc_param = {'solution_cnt': 15, 'max_iter': 500, 'trial_limit': 30, 'employed_legacy': True, 'onlooker_legacy': True, 'cv_on_train': False}

# %%
execution = OptimisationParamExecution(**param)
execution.fit(**abc_param)
# Out:
# Seed 0:
# Run CV of job 5
# (2500, 6) 5
# Seed 1:
# Run CV of job 5
# (2500, 6) 5
# Seed 2:
# Run CV of job 5
# (2500, 6) 5
# Seed 3:
# Run CV of job 5
# (2500, 6) 5
# Seed 4:
# Run CV of job 5
# (2500, 6) 5
# Seed 5:
# Run CV of job 5
# (2500, 6) 5
# Seed 6:
# Run CV of job 5
# (2500, 6) 5
# Seed 7:
# Run CV of job 5
# (2500, 6) 5
# Seed 8:
# Run CV of job 5
# (2500, 6) 5
# Seed 9:
# Run CV of job 5
# (2500, 6) 5
# Created ../data/abc_final2_n11_sol15_iter500_lim30.csv
